# %% [markdown]
# ### marginal effect　微分

# %%
import pandas as pd
import numpy as np
from statsmodels.discrete.discrete_model import Probit
import statsmodels.api as sm
import matplotlib.pyplot as plt
import sympy as sym
from sympy.plotting import plot
import math

# %%
x = sym.Symbol('x')

# %%
expr = sym.exp(0.01 * sym.log(x/10)) * sym.sin(sym.log(x/2)) + x/100
plot(expr, (x, 0, 60))

# %% [markdown]
# ### p(X)=1/(1+exp(-a-bx))
#
# coefficient =  [[0.08181119]]
# intercept =  [-2.80623879]
#
# econometrics 4を参照

# %%
expr = 1 / (1 + sym.exp(2.80623879 - 0.08181119* x))

# %%
plot(expr, (x, 0, 100))

# %%
#微分
deri = sym.diff(expr)
deri
# Out:
# 1.35377575263614*(0.00365200999279653/(0.06043186239722 + exp(-0.08181119*x))**2)*exp(-0.08181119*x)

# %%
#傾きの変化
plot(deri, (x, 0, 100))
